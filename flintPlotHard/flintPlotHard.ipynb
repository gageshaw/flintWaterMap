# %%
import flintPlotHardLib as sup
import importlib
import matplotlib.pyplot as plt

# %matplotlib inline
from matplotlib.widgets import Slider, Button, RadioButtons

importlib.reload(sup)

dataFile = '/Users/Gage/Desktop/FLINT/Data/10-16/Hardness/August 9,2016 Hardnessdata.xlsx'
locationFile = '/Users/Gage/Desktop/FLINT/Data/location/coordFiles/coordApril16EWDM.xlsx'

date = 'August 9, 2016'

saveName = date+'HardnessEWDM.pdf'


sup.plot(dataFile,locationFile, date,saveName)
