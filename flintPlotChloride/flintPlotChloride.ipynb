# %%
import flintPlotChlorideLib as sup
import importlib
import matplotlib.pyplot as plt

# %matplotlib inline
from matplotlib.widgets import Slider, Button, RadioButtons

importlib.reload(sup)

dataFile = '/Users/Gage/Desktop/FLINT/Data/10-16/Chloride/August 30,2016 Chloridedata.xlsx'
locationFile = '/Users/Gage/Desktop/FLINT/Data/location/coordFiles/coordApril16EWDM.xlsx'

date = 'August 30, 2016'

saveName = date+'ChlorideEWDM.pdf'


sup.plot(dataFile,locationFile,date,saveName)
