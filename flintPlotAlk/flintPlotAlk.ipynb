# %%
import flintPlotAlkLib as sup
import importlib
import matplotlib.pyplot as plt
from mpl_toolkits import mplot3d
from mpl_toolkits.mplot3d import Axes3D


# %matplotlib inline
importlib.reload(sup)

dataFile = '/Users/Gage/Desktop/FLINT/Data/12-15/December 6,2015 Alkalinitydata.xlsx'
locationFile = '/Users/Gage/Desktop/FLINT/Data/location/coordFiles/coordDecember15EWDM.xlsx'

date = 'August 30, 2016'

saveName = date+'AlkalinityEWDM.pdf'


sup.plot(dataFile,locationFile,date,saveName)
#sup.plot3d(dataFile,locationFile)
