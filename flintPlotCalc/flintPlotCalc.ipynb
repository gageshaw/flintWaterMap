# %%
import flintPlotCalcLib as sup
import importlib
import matplotlib.pyplot as plt

# %matplotlib inline
from matplotlib.widgets import Slider, Button, RadioButtons

importlib.reload(sup)

dataFile = '/Users/Gage/Desktop/FLINT/Data/12-16/December 4,2016 Calciumdata.xlsx'
locationFile = '/Users/Gage/Desktop/FLINT/Data/location/coordFiles/coordDecember16EWDM.xlsx'

date = 'December 4, 2016'

saveName = date+'CalciumEWDM.pdf'


sup.plot(dataFile,locationFile,date,saveName)
