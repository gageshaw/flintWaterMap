# %%
import flintPlot1117freeClLib as sup
import importlib
import matplotlib.pyplot as plt

# %matplotlib inline
from matplotlib.widgets import Slider, Button, RadioButtons

importlib.reload(sup)

dataFile = '/Users/Gage/Downloads/drive-download-20200908T071239Z-001/May 26,2010freeclres.xlsx'
locationFile = '/Users/Gage/Desktop/FLINT/Data/location/coordFiles/coord2010-2011MOR.xlsx'
dataType = 'Chlorine Residual'
unit = '(mg/l)'
date = 'May 26, 2010'

saveName = date+'freeclres.pdf'


sup.plot(dataFile,locationFile, unit,date,saveName)
