# %%
import flintPlotOrthoLib as sup
import importlib
import matplotlib.pyplot as plt
import flintPlot1117lib as lib
# %matplotlib inline
from matplotlib.widgets import Slider, Button, RadioButtons

importlib.reload(sup)

dataFile = '/Users/Gage/Desktop/FLINT/Data/10-16/Orthophosphate/August 30,2016 Orthophosphatedata.xlsx'
locationFile = '/Users/Gage/Desktop/FLINT/Data/location/coordFiles/coordApril16EWDM.xlsx'

date = 'August 30, 2016'

saveName = date+'OrthophosphateEWDM.pdf'

#Xscat,Yscat,Zscat,Xcont,Ycont,Zcont,T,F = lib.readExcel(dataFile,locationFile)
#lib.contourScatter3d(Xcont,Ycont,Zcont,Xscat,Yscat,Zscat)
sup.plot(dataFile,locationFile, date,saveName)
