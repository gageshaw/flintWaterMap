# %%
import flintPlotTempLib as sup
import importlib
import matplotlib.pyplot as plt

# %matplotlib inline
from matplotlib.widgets import Slider, Button, RadioButtons

importlib.reload(sup)

dataFile = '/Users/Gage/Desktop/FLINT/Data/10-16/Temperature/August 30,2016 Tempdata.xlsx'
locationFile = '/Users/Gage/Desktop/FLINT/Data/location/coordFiles/coordApril16EWDM.xlsx'

date = 'August 30, 2016'

saveName = date+'TemperatureEWDM.pdf'


sup.plot(dataFile,locationFile, date,saveName)
