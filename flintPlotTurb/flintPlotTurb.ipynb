# %%
import flintPlotTurbLib as sup
import importlib
import matplotlib.pyplot as plt

# %matplotlib inline
from matplotlib.widgets import Slider, Button, RadioButtons

importlib.reload(sup)

dataFile = '/Users/Gage/Desktop/FLINT/Data/2-16/February 7,2016 Turbiditydata.xlsx'
locationFile = '/Users/Gage/Desktop/FLINT/Data/location/coordFiles/coordDecember15EWDM.xlsx'

date = 'February 7, 2016'

saveName = date+'TurbidityEWDM.pdf'


sup.plot(dataFile,locationFile, date,saveName)
